# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# The zip object packs each array into a tuple. 
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 724

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | comodoro rivadavia
# Processing Record 5 of Set 1 | leshukonskoye
# Processing Record 6 of Set 1 | te anau
# Processing Record 7 of Set 1 | saint-augustin
# Processing Record 8 of Set 1 | morro bay
# Processing Record 9 of Set 1 | sangar
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | dabat
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | mbandaka
# Processing Record 14 of Set 1 | hutchinson
# Processing Record 15 of Set 1 | sobolevo
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | half moon bay
# Processing Record 18 of Set 1 | ekimchan
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | port elizabeth
# Processing Record 23 of Set 1 | faanui
# Processing Record 24 of Set 1 | mahebourg
# Processing Record 25 of Set 1 | tasiilaq
# Processing Record 26 of Set 1 | bambous virieux
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | upernavik
# Processing Record 29 of Set 1 | daru
# Processing Record 30 of Set 1 | nikolskoye
# Processing Record 31 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 1 | arraial do cabo
# Processing Record 33 of Set 1 | lebu
# Processing Record 34 of Set 1 | zhangjiakou
# Processing Record 35 of Set 1 | yar-sale
# Processing Record 36 of Set 1 | batagay-alyta
# Processing Record 37 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 1 | chokurdakh
# Processing Record 39 of Set 1 | makakilo city
# Processing Record 40 of Set 1 | azare
# Processing Record 41 of Set 1 | vila velha
# Processing Record 42 of Set 1 | paamiut
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | aklavik
# Processing Record 45 of Set 1 | kahului
# Processing Record 46 of Set 1 | arman
# Processing Record 47 of Set 1 | clyde river
# Processing Record 48 of Set 1 | nome
# Processing Record 49 of Set 1 | avera
# Processing Record 50 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 2 | caravelas
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 2 | carnarvon
# Processing Record 5 of Set 2 | barranca
# Processing Record 6 of Set 2 | cape town
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 2 | ayan
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 2 | puerto ayora
# Processing Record 14 of Set 2 | karratha
# Processing Record 15 of Set 2 | muros
# Processing Record 16 of Set 2 | gamba
# Processing Record 17 of Set 2 | yeppoon
# Processing Record 18 of Set 2 | jamestown
# Processing Record 19 of Set 2 | cidreira
# Processing Record 20 of Set 2 | bethel
# Processing Record 21 of Set 2 | tuatapere
# Processing Record 22 of Set 2 | galiwinku
# City not found. Skipping...
# Processing Record 23 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 2 | bengkulu
# Processing Record 25 of Set 2 | tranas
# Processing Record 26 of Set 2 | miranda de ebro
# Processing Record 27 of Set 2 | turbat
# Processing Record 28 of Set 2 | saint-philippe
# Processing Record 29 of Set 2 | barrow
# Processing Record 30 of Set 2 | ribeira grande
# Processing Record 31 of Set 2 | le port
# Processing Record 32 of Set 2 | cabo san lucas
# Processing Record 33 of Set 2 | vanavara
# Processing Record 34 of Set 2 | maxixe
# Processing Record 35 of Set 2 | saint-joseph
# Processing Record 36 of Set 2 | pangnirtung
# Processing Record 37 of Set 2 | new norfolk
# Processing Record 38 of Set 2 | baherden
# Processing Record 39 of Set 2 | cuajinicuilapa
# Processing Record 40 of Set 2 | aberdeen
# Processing Record 41 of Set 2 | ihosy
# Processing Record 42 of Set 2 | atuona
# Processing Record 43 of Set 2 | avarua
# Processing Record 44 of Set 2 | busselton
# Processing Record 45 of Set 2 | khatanga
# Processing Record 46 of Set 2 | talnakh
# Processing Record 47 of Set 2 | hithadhoo
# Processing Record 48 of Set 2 | hilo
# Processing Record 49 of Set 2 | armacao dos buzios
# City not found. Skipping...
# Processing Record 50 of Set 2 | pangody
# Processing Record 1 of Set 3 | ilulissat
# Processing Record 2 of Set 3 | provideniya
# Processing Record 3 of Set 3 | nicoya
# Processing Record 4 of Set 3 | praia
# Processing Record 5 of Set 3 | mar del plata
# Processing Record 6 of Set 3 | boende
# Processing Record 7 of Set 3 | ambilobe
# Processing Record 8 of Set 3 | camacha
# Processing Record 9 of Set 3 | santa luzia
# Processing Record 10 of Set 3 | haines junction
# Processing Record 11 of Set 3 | hohhot
# Processing Record 12 of Set 3 | vao
# Processing Record 13 of Set 3 | tuktoyaktuk
# Processing Record 14 of Set 3 | dzyhivka
# Processing Record 15 of Set 3 | ogaminana
# Processing Record 16 of Set 3 | spas-klepiki
# Processing Record 17 of Set 3 | victoria
# Processing Record 18 of Set 3 | longjiang
# Processing Record 19 of Set 3 | ostrovnoy
# Processing Record 20 of Set 3 | okhotsk
# Processing Record 21 of Set 3 | bull savanna
# Processing Record 22 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 23 of Set 3 | iqaluit
# Processing Record 24 of Set 3 | ascension
# Processing Record 25 of Set 3 | sijunjung
# Processing Record 26 of Set 3 | north augusta
# Processing Record 27 of Set 3 | aqtobe
# Processing Record 28 of Set 3 | castro
# Processing Record 29 of Set 3 | east london
# Processing Record 30 of Set 3 | kavaratti
# Processing Record 31 of Set 3 | dikson
# Processing Record 32 of Set 3 | lincoln
# Processing Record 33 of Set 3 | atasu
# Processing Record 34 of Set 3 | strezhevoy
# Processing Record 35 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 3 | bud
# Processing Record 37 of Set 3 | rio verde de mato grosso
# Processing Record 38 of Set 3 | nizhniy tsasuchey
# Processing Record 39 of Set 3 | tarko-sale
# Processing Record 40 of Set 3 | leningradskiy
# Processing Record 41 of Set 3 | chapais
# Processing Record 42 of Set 3 | lagoa
# Processing Record 43 of Set 3 | berlevag
# Processing Record 44 of Set 3 | kulu
# Processing Record 45 of Set 3 | ahipara
# Processing Record 46 of Set 3 | seminole
# Processing Record 47 of Set 3 | gari
# Processing Record 48 of Set 3 | vico equense
# Processing Record 49 of Set 3 | byron bay
# Processing Record 50 of Set 3 | mehran
# Processing Record 1 of Set 4 | amga
# Processing Record 2 of Set 4 | sitka
# Processing Record 3 of Set 4 | nouadhibou
# Processing Record 4 of Set 4 | nha trang
# Processing Record 5 of Set 4 | misratah
# Processing Record 6 of Set 4 | lasa
# Processing Record 7 of Set 4 | hobart
# Processing Record 8 of Set 4 | forrest city
# Processing Record 9 of Set 4 | north bend
# Processing Record 10 of Set 4 | lompoc
# Processing Record 11 of Set 4 | saldanha
# Processing Record 12 of Set 4 | kalamazoo
# Processing Record 13 of Set 4 | butaritari
# Processing Record 14 of Set 4 | santa isabel
# Processing Record 15 of Set 4 | lishui
# Processing Record 16 of Set 4 | vieux-habitants
# Processing Record 17 of Set 4 | salalah
# Processing Record 18 of Set 4 | san rafael
# Processing Record 19 of Set 4 | richards bay
# Processing Record 20 of Set 4 | santa isabel do rio negro
# Processing Record 21 of Set 4 | kavieng
# Processing Record 22 of Set 4 | samarai
# Processing Record 23 of Set 4 | kaitangata
# Processing Record 24 of Set 4 | banjar
# Processing Record 25 of Set 4 | tynda
# Processing Record 26 of Set 4 | pevek
# Processing Record 27 of Set 4 | mongu
# Processing Record 28 of Set 4 | kismayo
# Processing Record 29 of Set 4 | straumen
# Processing Record 30 of Set 4 | krasnoselkup
# Processing Record 31 of Set 4 | koslan
# Processing Record 32 of Set 4 | gazli
# Processing Record 33 of Set 4 | saskylakh
# Processing Record 34 of Set 4 | souillac
# Processing Record 35 of Set 4 | bizhbulyak
# Processing Record 36 of Set 4 | lata
# Processing Record 37 of Set 4 | klaksvik
# Processing Record 38 of Set 4 | isangel
# Processing Record 39 of Set 4 | bestobe
# Processing Record 40 of Set 4 | inhambane
# Processing Record 41 of Set 4 | atar
# Processing Record 42 of Set 4 | panguna
# Processing Record 43 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 4 | kuching
# Processing Record 45 of Set 4 | monrovia
# Processing Record 46 of Set 4 | mackay
# Processing Record 47 of Set 4 | torbay
# Processing Record 48 of Set 4 | mangrol
# Processing Record 49 of Set 4 | tiksi
# Processing Record 50 of Set 4 | yellowknife
# Processing Record 1 of Set 5 | guachucal
# Processing Record 2 of Set 5 | broken hill
# Processing Record 3 of Set 5 | norman wells
# Processing Record 4 of Set 5 | anadyr
# Processing Record 5 of Set 5 | ancud
# Processing Record 6 of Set 5 | iba
# Processing Record 7 of Set 5 | sakakah
# Processing Record 8 of Set 5 | lemesos
# City not found. Skipping...
# Processing Record 9 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 5 | kailua
# Processing Record 11 of Set 5 | recas
# Processing Record 12 of Set 5 | qaanaaq
# Processing Record 13 of Set 5 | port macquarie
# Processing Record 14 of Set 5 | port hedland
# Processing Record 15 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 16 of Set 5 | bayir
# Processing Record 17 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 5 | saint anthony
# Processing Record 19 of Set 5 | ridgecrest
# Processing Record 20 of Set 5 | akyab
# Processing Record 21 of Set 5 | phuket
# Processing Record 22 of Set 5 | artyom
# Processing Record 23 of Set 5 | nouakchott
# Processing Record 24 of Set 5 | georgetown
# Processing Record 25 of Set 5 | port-gentil
# Processing Record 26 of Set 5 | cherskiy
# Processing Record 27 of Set 5 | gold coast
# Processing Record 28 of Set 5 | airai
# Processing Record 29 of Set 5 | gallup
# Processing Record 30 of Set 5 | itupiranga
# Processing Record 31 of Set 5 | quatre cocos
# Processing Record 32 of Set 5 | sarangani
# Processing Record 33 of Set 5 | katsuura
# Processing Record 34 of Set 5 | naze
# Processing Record 35 of Set 5 | bonavista
# Processing Record 36 of Set 5 | burica
# City not found. Skipping...
# Processing Record 37 of Set 5 | thompson
# Processing Record 38 of Set 5 | kefamenanu
# Processing Record 39 of Set 5 | gat
# Processing Record 40 of Set 5 | tahta
# Processing Record 41 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 5 | guapiles
# Processing Record 43 of Set 5 | qasigiannguit
# Processing Record 44 of Set 5 | benguela
# Processing Record 45 of Set 5 | husavik
# Processing Record 46 of Set 5 | wattegama
# Processing Record 47 of Set 5 | flinders
# Processing Record 48 of Set 5 | okha
# Processing Record 49 of Set 5 | turukhansk
# Processing Record 50 of Set 5 | ixtapa
# Processing Record 1 of Set 6 | aykhal
# Processing Record 2 of Set 6 | puksoozero
# Processing Record 3 of Set 6 | vila franca do campo
# Processing Record 4 of Set 6 | miri
# Processing Record 5 of Set 6 | the valley
# Processing Record 6 of Set 6 | belmonte
# Processing Record 7 of Set 6 | hofn
# Processing Record 8 of Set 6 | longyearbyen
# Processing Record 9 of Set 6 | shu
# Processing Record 10 of Set 6 | vostok
# Processing Record 11 of Set 6 | san cristobal
# Processing Record 12 of Set 6 | xining
# Processing Record 13 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 6 | russell
# Processing Record 15 of Set 6 | salinas
# Processing Record 16 of Set 6 | novoagansk
# Processing Record 17 of Set 6 | altamont
# Processing Record 18 of Set 6 | lodja
# Processing Record 19 of Set 6 | astana
# Processing Record 20 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 21 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 6 | lichtenburg
# Processing Record 24 of Set 6 | whittlesea
# Processing Record 25 of Set 6 | impfondo
# Processing Record 26 of Set 6 | kano
# Processing Record 27 of Set 6 | westport
# Processing Record 28 of Set 6 | raga
# Processing Record 29 of Set 6 | port hardy
# Processing Record 30 of Set 6 | dingle
# Processing Record 31 of Set 6 | hami
# Processing Record 32 of Set 6 | jinka
# Processing Record 33 of Set 6 | moron
# Processing Record 34 of Set 6 | tazovskiy
# Processing Record 35 of Set 6 | kodiak
# Processing Record 36 of Set 6 | hof
# Processing Record 37 of Set 6 | tezu
# Processing Record 38 of Set 6 | patiya
# Processing Record 39 of Set 6 | sao joao da barra
# Processing Record 40 of Set 6 | komsomolskiy
# Processing Record 41 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 42 of Set 6 | fortuna
# Processing Record 43 of Set 6 | palmer
# Processing Record 44 of Set 6 | saint-tite
# Processing Record 45 of Set 6 | ponta do sol
# Processing Record 46 of Set 6 | surt
# Processing Record 47 of Set 6 | dalbandin
# Processing Record 48 of Set 6 | alofi
# Processing Record 49 of Set 6 | shieli
# Processing Record 50 of Set 6 | phaltan
# Processing Record 1 of Set 7 | sheridan
# Processing Record 2 of Set 7 | coari
# Processing Record 3 of Set 7 | oussouye
# Processing Record 4 of Set 7 | yaan
# Processing Record 5 of Set 7 | tomatlan
# Processing Record 6 of Set 7 | takoradi
# Processing Record 7 of Set 7 | luderitz
# Processing Record 8 of Set 7 | newport news
# Processing Record 9 of Set 7 | koltubanovskiy
# Processing Record 10 of Set 7 | antofagasta
# Processing Record 11 of Set 7 | businga
# Processing Record 12 of Set 7 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 13 of Set 7 | lensk
# Processing Record 14 of Set 7 | sile
# Processing Record 15 of Set 7 | kalmanka
# Processing Record 16 of Set 7 | fort nelson
# Processing Record 17 of Set 7 | awjilah
# Processing Record 18 of Set 7 | honningsvag
# Processing Record 19 of Set 7 | igrim
# Processing Record 20 of Set 7 | ayagoz
# Processing Record 21 of Set 7 | bukama
# Processing Record 22 of Set 7 | montgomery
# Processing Record 23 of Set 7 | nanortalik
# Processing Record 24 of Set 7 | riyadh
# Processing Record 25 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 26 of Set 7 | padang
# Processing Record 27 of Set 7 | tommot
# Processing Record 28 of Set 7 | balikpapan
# Processing Record 29 of Set 7 | namatanai
# Processing Record 30 of Set 7 | annau
# Processing Record 31 of Set 7 | son la
# Processing Record 32 of Set 7 | moiyabana
# City not found. Skipping...
# Processing Record 33 of Set 7 | severnyy
# Processing Record 34 of Set 7 | boden
# Processing Record 35 of Set 7 | esperance
# Processing Record 36 of Set 7 | pisco
# Processing Record 37 of Set 7 | chuy
# Processing Record 38 of Set 7 | bluefields
# Processing Record 39 of Set 7 | colquiri
# Processing Record 40 of Set 7 | bismarck
# Processing Record 41 of Set 7 | alto araguaia
# Processing Record 42 of Set 7 | sao gabriel da cachoeira
# Processing Record 43 of Set 7 | broome
# Processing Record 44 of Set 7 | bathsheba
# Processing Record 45 of Set 7 | merrill
# Processing Record 46 of Set 7 | kulachi
# Processing Record 47 of Set 7 | chegem
# Processing Record 48 of Set 7 | san andres
# Processing Record 49 of Set 7 | meulaboh
# Processing Record 50 of Set 7 | constitucion
# Processing Record 1 of Set 8 | skelleftea
# Processing Record 2 of Set 8 | ambon
# Processing Record 3 of Set 8 | pangoa
# Processing Record 4 of Set 8 | marsh harbour
# Processing Record 5 of Set 8 | kilindoni
# Processing Record 6 of Set 8 | pacific grove
# Processing Record 7 of Set 8 | la ronge
# Processing Record 8 of Set 8 | agadez
# Processing Record 9 of Set 8 | taveta
# Processing Record 10 of Set 8 | uwayl
# City not found. Skipping...
# Processing Record 11 of Set 8 | truth or consequences
# Processing Record 12 of Set 8 | geraldton
# Processing Record 13 of Set 8 | jinji
# Processing Record 14 of Set 8 | omsukchan
# Processing Record 15 of Set 8 | gurkovo
# Processing Record 16 of Set 8 | amapa
# Processing Record 17 of Set 8 | dera din panah
# City not found. Skipping...
# Processing Record 18 of Set 8 | aswan
# Processing Record 19 of Set 8 | dylym
# Processing Record 20 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 21 of Set 8 | banda aceh
# Processing Record 22 of Set 8 | kruisfontein
# Processing Record 23 of Set 8 | ocala
# Processing Record 24 of Set 8 | mount gambier
# Processing Record 25 of Set 8 | tiznit
# Processing Record 26 of Set 8 | cockburn town
# Processing Record 27 of Set 8 | lavrentiya
# Processing Record 28 of Set 8 | angoram
# Processing Record 29 of Set 8 | aripuana
# Processing Record 30 of Set 8 | hirara
# Processing Record 31 of Set 8 | fort william
# Processing Record 32 of Set 8 | kyren
# Processing Record 33 of Set 8 | homer
# Processing Record 34 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 35 of Set 8 | sterling
# Processing Record 36 of Set 8 | salinopolis
# Processing Record 37 of Set 8 | port blair
# Processing Record 38 of Set 8 | garissa
# Processing Record 39 of Set 8 | great yarmouth
# Processing Record 40 of Set 8 | skjervoy
# Processing Record 41 of Set 8 | muisne
# Processing Record 42 of Set 8 | los llanos de aridane
# Processing Record 43 of Set 8 | little current
# Processing Record 44 of Set 8 | yanam
# Processing Record 45 of Set 8 | lesnoy
# Processing Record 46 of Set 8 | touros
# Processing Record 47 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 48 of Set 8 | buraydah
# Processing Record 49 of Set 8 | adre
# Processing Record 50 of Set 8 | san-pedro
# Processing Record 1 of Set 9 | taytay
# Processing Record 2 of Set 9 | emporia
# Processing Record 3 of Set 9 | henties bay
# Processing Record 4 of Set 9 | bilibino
# Processing Record 5 of Set 9 | malatya
# Processing Record 6 of Set 9 | kununurra
# Processing Record 7 of Set 9 | boa vista
# Processing Record 8 of Set 9 | marrakesh
# Processing Record 9 of Set 9 | safford
# Processing Record 10 of Set 9 | puerto leguizamo
# Processing Record 11 of Set 9 | sorland
# Processing Record 12 of Set 9 | acari
# Processing Record 13 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 14 of Set 9 | bulgan
# Processing Record 15 of Set 9 | mahon
# Processing Record 16 of Set 9 | labuhan
# Processing Record 17 of Set 9 | ranong
# Processing Record 18 of Set 9 | mayo
# Processing Record 19 of Set 9 | dukat
# Processing Record 20 of Set 9 | bairiki
# Processing Record 21 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 9 | pasighat
# Processing Record 23 of Set 9 | logon
# Processing Record 24 of Set 9 | mengyin
# Processing Record 25 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 9 | nemuro
# Processing Record 27 of Set 9 | grindavik
# Processing Record 28 of Set 9 | morwell
# Processing Record 29 of Set 9 | cleveland
# Processing Record 30 of Set 9 | matara
# Processing Record 31 of Set 9 | ratnagiri
# Processing Record 32 of Set 9 | sertania
# Processing Record 33 of Set 9 | xinpu
# Processing Record 34 of Set 9 | waipawa
# Processing Record 35 of Set 9 | honggang
# Processing Record 36 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 9 | portland
# Processing Record 38 of Set 9 | laguna
# Processing Record 39 of Set 9 | faya
# Processing Record 40 of Set 9 | plettenberg bay
# Processing Record 41 of Set 9 | omegna
# Processing Record 42 of Set 9 | ucluelet
# Processing Record 43 of Set 9 | hazleton
# Processing Record 44 of Set 9 | aporawan
# City not found. Skipping...
# Processing Record 45 of Set 9 | nelson bay
# Processing Record 46 of Set 9 | toyooka
# Processing Record 47 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 48 of Set 9 | zwedru
# Processing Record 49 of Set 9 | bollnas
# Processing Record 50 of Set 9 | kaduy
# Processing Record 1 of Set 10 | sur
# Processing Record 2 of Set 10 | socoltenango
# Processing Record 3 of Set 10 | le marin
# Processing Record 4 of Set 10 | iranshahr
# Processing Record 5 of Set 10 | la roche-sur-yon
# Processing Record 6 of Set 10 | alcantara
# Processing Record 7 of Set 10 | aitape
# Processing Record 8 of Set 10 | darnah
# Processing Record 9 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 10 | belaya gora
# Processing Record 11 of Set 10 | lisakovsk
# Processing Record 12 of Set 10 | grand forks
# Processing Record 13 of Set 10 | jian
# Processing Record 14 of Set 10 | carutapera
# Processing Record 15 of Set 10 | saint-pierre
# Processing Record 16 of Set 10 | sherman
# Processing Record 17 of Set 10 | jicin
# Processing Record 18 of Set 10 | waitati
# Processing Record 19 of Set 10 | beaverlodge
# Processing Record 20 of Set 10 | chiang kham
# Processing Record 21 of Set 10 | guerrero negro
# Processing Record 22 of Set 10 | zyryanka
# Processing Record 23 of Set 10 | derzhavinsk
# Processing Record 24 of Set 10 | leh
# Processing Record 25 of Set 10 | suntar
# Processing Record 26 of Set 10 | orizona
# Processing Record 27 of Set 10 | ripon
# Processing Record 28 of Set 10 | bria
# Processing Record 29 of Set 10 | mikkeli
# Processing Record 30 of Set 10 | mwanza
# Processing Record 31 of Set 10 | danilovka
# Processing Record 32 of Set 10 | hualmay
# Processing Record 33 of Set 10 | camana
# Processing Record 34 of Set 10 | bahia blanca
# Processing Record 35 of Set 10 | mathbaria
# Processing Record 36 of Set 10 | toamasina
# Processing Record 37 of Set 10 | batemans bay
# Processing Record 38 of Set 10 | lempaala
# Processing Record 39 of Set 10 | palembang
# Processing Record 40 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 41 of Set 10 | batticaloa
# Processing Record 42 of Set 10 | olafsvik
# Processing Record 43 of Set 10 | luanda
# Processing Record 44 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 45 of Set 10 | plerin
# Processing Record 46 of Set 10 | rabat
# Processing Record 47 of Set 10 | arlit
# Processing Record 48 of Set 10 | shaki
# Processing Record 49 of Set 10 | qaqortoq
# Processing Record 50 of Set 10 | osakarovka
# Processing Record 1 of Set 11 | la libertad
# Processing Record 2 of Set 11 | kijang
# Processing Record 3 of Set 11 | ketchikan
# Processing Record 4 of Set 11 | severo-kurilsk
# Processing Record 5 of Set 11 | seddon
# Processing Record 6 of Set 11 | bubaque
# Processing Record 7 of Set 11 | bara
# Processing Record 8 of Set 11 | svetlogorsk
# Processing Record 9 of Set 11 | las lomas
# Processing Record 10 of Set 11 | colac
# Processing Record 11 of Set 11 | houston
# Processing Record 12 of Set 11 | odienne
# Processing Record 13 of Set 11 | krivosheino
# Processing Record 14 of Set 11 | jiangyou
# Processing Record 15 of Set 11 | pozo colorado
# Processing Record 16 of Set 11 | namibe
# Processing Record 17 of Set 11 | gollere
# City not found. Skipping...
# Processing Record 18 of Set 11 | carmelo
# Processing Record 19 of Set 11 | verkhnevilyuysk
# Processing Record 20 of Set 11 | taltal
# Processing Record 21 of Set 11 | novobiryusinskiy
# Processing Record 22 of Set 11 | lock haven
# Processing Record 23 of Set 11 | roald
# Processing Record 24 of Set 11 | beloha
# Processing Record 25 of Set 11 | gizo
# Processing Record 26 of Set 11 | terrace bay
# Processing Record 27 of Set 11 | yerbogachen
# Processing Record 28 of Set 11 | khani
# Processing Record 29 of Set 11 | asau
# Processing Record 30 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 11 | rapid valley
# Processing Record 32 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 11 | dinsor
# City not found. Skipping...
# Processing Record 34 of Set 11 | trelleborg
# Processing Record 35 of Set 11 | bloomfield
# Processing Record 36 of Set 11 | montijo
# Processing Record 37 of Set 11 | taoudenni
# Processing Record 38 of Set 11 | disna
# Processing Record 39 of Set 11 | malanje
# Processing Record 40 of Set 11 | koutiala
# Processing Record 41 of Set 11 | norrtalje
# Processing Record 42 of Set 11 | ust-nera
# Processing Record 43 of Set 11 | talaya
# Processing Record 44 of Set 11 | vysha
# Processing Record 45 of Set 11 | porto walter
# Processing Record 46 of Set 11 | vardo
# Processing Record 47 of Set 11 | igdir
# Processing Record 48 of Set 11 | siavonga
# Processing Record 49 of Set 11 | jambi
# Processing Record 50 of Set 11 | yunjinghong
# City not found. Skipping...
# Processing Record 1 of Set 12 | yashkul
# Processing Record 2 of Set 12 | znamenskoye
# Processing Record 3 of Set 12 | jalu
# Processing Record 4 of Set 12 | port lincoln
# Processing Record 5 of Set 12 | umm kaddadah
# Processing Record 6 of Set 12 | heihe
# Processing Record 7 of Set 12 | saint-gaudens
# Processing Record 8 of Set 12 | goderich
# Processing Record 9 of Set 12 | mehamn
# Processing Record 10 of Set 12 | grand baie
# Processing Record 11 of Set 12 | khovu-aksy
# Processing Record 12 of Set 12 | san patricio
# Processing Record 13 of Set 12 | zaysan
# Processing Record 14 of Set 12 | verkh-suetka
# Processing Record 15 of Set 12 | kommunar
# Processing Record 16 of Set 12 | verkhnetulomskiy
# Processing Record 17 of Set 12 | hambantota
# Processing Record 18 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 12 | pimentel
# Processing Record 20 of Set 12 | moba
# Processing Record 21 of Set 12 | kyra
# Processing Record 22 of Set 12 | kichera
# Processing Record 23 of Set 12 | gudari
# Processing Record 24 of Set 12 | san quintin
# Processing Record 25 of Set 12 | vokhtoga
# Processing Record 26 of Set 12 | graham
# Processing Record 27 of Set 12 | brae
# Processing Record 28 of Set 12 | xambioa
# Processing Record 29 of Set 12 | rangoon
# Processing Record 30 of Set 12 | cap malheureux
# Processing Record 31 of Set 12 | buala
# Processing Record 32 of Set 12 | lima
# Processing Record 33 of Set 12 | aksu
# Processing Record 34 of Set 12 | hermiston
# Processing Record 35 of Set 12 | hamilton
# Processing Record 36 of Set 12 | dunedin
# Processing Record 37 of Set 12 | kutum
# Processing Record 38 of Set 12 | presidencia roque saenz pena
# Processing Record 39 of Set 12 | cururupu
# Processing Record 40 of Set 12 | shahrud
# Processing Record 41 of Set 12 | taitung
# Processing Record 42 of Set 12 | kuala kedah
# Processing Record 43 of Set 12 | moshenskoye
# Processing Record 44 of Set 12 | harper
# Processing Record 45 of Set 12 | rio grande
# Processing Record 46 of Set 12 | havelock
# Processing Record 47 of Set 12 | lawrenceburg
# Processing Record 48 of Set 12 | adrar
# Processing Record 49 of Set 12 | grand gaube
# Processing Record 50 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 1 of Set 13 | hasaki
# Processing Record 2 of Set 13 | atambua
# Processing Record 3 of Set 13 | birjand
# Processing Record 4 of Set 13 | trinidad
# Processing Record 5 of Set 13 | acarau
# Processing Record 6 of Set 13 | shimoda
# Processing Record 7 of Set 13 | kaili
# Processing Record 8 of Set 13 | storsteinnes
# Processing Record 9 of Set 13 | manhattan
# Processing Record 10 of Set 13 | bosansko grahovo
# Processing Record 11 of Set 13 | gboko
# Processing Record 12 of Set 13 | lorengau
# Processing Record 13 of Set 13 | bouillante
# Processing Record 14 of Set 13 | catamarca
# Processing Record 15 of Set 13 | raymond
# Processing Record 16 of Set 13 | arkansas city
# Processing Record 17 of Set 13 | dangriga
# Processing Record 18 of Set 13 | codrington
# Processing Record 19 of Set 13 | dossor
# Processing Record 20 of Set 13 | tura
# Processing Record 21 of Set 13 | tevriz
# Processing Record 22 of Set 13 | cartagena
# Processing Record 23 of Set 13 | cazaje
# City not found. Skipping...
# Processing Record 24 of Set 13 | coihaique
# Processing Record 25 of Set 13 | embonas
# Processing Record 26 of Set 13 | pinega
# Processing Record 27 of Set 13 | guaraniacu
# Processing Record 28 of Set 13 | iquique
# Processing Record 29 of Set 13 | ust-kuyga
# Processing Record 30 of Set 13 | monclova
# Processing Record 31 of Set 13 | narsaq
# Processing Record 32 of Set 13 | newton
# Processing Record 33 of Set 13 | araguacu
# Processing Record 34 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 35 of Set 13 | sayyan
# Processing Record 36 of Set 13 | kaura namoda
# Processing Record 37 of Set 13 | ust-kan
# Processing Record 38 of Set 13 | qitaihe
# Processing Record 39 of Set 13 | san mateo del mar
# Processing Record 40 of Set 13 | galle
# Processing Record 41 of Set 13 | borisoglebskiy
# Processing Record 42 of Set 13 | nantucket
# Processing Record 43 of Set 13 | sola
# Processing Record 44 of Set 13 | port augusta
# Processing Record 45 of Set 13 | olinda
# Processing Record 46 of Set 13 | llangefni
# Processing Record 47 of Set 13 | stolin
# Processing Record 48 of Set 13 | mandalgovi
# Processing Record 49 of Set 13 | mbigou
# Processing Record 50 of Set 13 | puchezh
# Processing Record 1 of Set 14 | sibolga
# Processing Record 2 of Set 14 | kathu
# Processing Record 3 of Set 14 | enschede
# Processing Record 4 of Set 14 | iberia
# Processing Record 5 of Set 14 | newport
# Processing Record 6 of Set 14 | norfolk
# Processing Record 7 of Set 14 | palatka
# Processing Record 8 of Set 14 | morondava
# Processing Record 9 of Set 14 | canaries
# Processing Record 10 of Set 14 | bradford
# Processing Record 11 of Set 14 | kieta
# Processing Record 12 of Set 14 | hyderabad
# Processing Record 13 of Set 14 | passos
# Processing Record 14 of Set 14 | asfi
# Processing Record 15 of Set 14 | gladstone
# Processing Record 16 of Set 14 | christchurch
# Processing Record 17 of Set 14 | jiancheng
# Processing Record 18 of Set 14 | hailar
# Processing Record 19 of Set 14 | auki
# Processing Record 20 of Set 14 | pedernales
# Processing Record 21 of Set 14 | charters towers
# Processing Record 22 of Set 14 | snyder
# Processing Record 23 of Set 14 | margate
# Processing Record 24 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 14 | alexandria
# Processing Record 26 of Set 14 | omaruru
# Processing Record 27 of Set 14 | ngunguru
# Processing Record 28 of Set 14 | xacmaz
# Processing Record 29 of Set 14 | tabou
# Processing Record 30 of Set 14 | katangli
# Processing Record 31 of Set 14 | chimbote
# Processing Record 32 of Set 14 | waingapu
# Processing Record 33 of Set 14 | point fortin
# Processing Record 34 of Set 14 | rundu
# Processing Record 35 of Set 14 | vaitape
# Processing Record 36 of Set 14 | la asuncion
# Processing Record 37 of Set 14 | maniitsoq
# Processing Record 38 of Set 14 | hay river
# Processing Record 39 of Set 14 | ballina
# Processing Record 40 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 41 of Set 14 | morena
# Processing Record 42 of Set 14 | blackwater
# Processing Record 43 of Set 14 | tual
# Processing Record 44 of Set 14 | baruun-urt
# Processing Record 45 of Set 14 | mayskiy
# Processing Record 46 of Set 14 | takhtamygda
# Processing Record 47 of Set 14 | griffith
# Processing Record 48 of Set 14 | vila
# Processing Record 49 of Set 14 | teya
# Processing Record 50 of Set 14 | kattivakkam
# Processing Record 1 of Set 15 | myanaung
# Processing Record 2 of Set 15 | kandi
# Processing Record 3 of Set 15 | ruteng
# Processing Record 4 of Set 15 | yumen
# Processing Record 5 of Set 15 | juybar
# Processing Record 6 of Set 15 | greystones
# Processing Record 7 of Set 15 | kloulklubed
# Processing Record 8 of Set 15 | halifax
# Processing Record 9 of Set 15 | alta floresta
# Processing Record 10 of Set 15 | luoyang
# Processing Record 11 of Set 15 | mpophomeni
# Processing Record 12 of Set 15 | katha
# City not found. Skipping...
# Processing Record 13 of Set 15 | shirgaon
# Processing Record 14 of Set 15 | edremit
# Processing Record 15 of Set 15 | tashla
# Processing Record 16 of Set 15 | valencia
# Processing Record 17 of Set 15 | kirkwood
# Processing Record 18 of Set 15 | urengoy
# Processing Record 19 of Set 15 | upata
# Processing Record 20 of Set 15 | canals
# Processing Record 21 of Set 15 | eyl
# Processing Record 22 of Set 15 | ulaangom
# Processing Record 23 of Set 15 | tigil
# Processing Record 24 of Set 15 | araouane
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Punta Arenas -53.1500  -70.9167     48.31        71          75
# 1  Comodoro Rivadavia -45.8667  -67.5000     84.06        21           0
# 2       Leshukonskoye  64.8989   45.7622      8.20        98          97
# 3             Te Anau -45.4167  167.7167     62.02        79         100
# 4      Saint-Augustin  51.2260  -58.6502     23.72        89         100
#
#    Wind Speed Country Current Description
# 0        8.05      CL       broken clouds
# 1       14.97      AR           clear sky
# 2        2.44      RU     overcast clouds
# 3        4.99      NZ     overcast clouds
# 4       23.73      CA     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0        Punta Arenas      CL -53.1500  -70.9167     48.31        71
# 1  Comodoro Rivadavia      AR -45.8667  -67.5000     84.06        21
# 2       Leshukonskoye      RU  64.8989   45.7622      8.20        98
# 3             Te Anau      NZ -45.4167  167.7167     62.02        79
# 4      Saint-Augustin      CA  51.2260  -58.6502     23.72        89
#
#    Cloudiness  Wind Speed Current Description
# 0          75        8.05       broken clouds
# 1           0       14.97           clear sky
# 2          97        2.44     overcast clouds
# 3         100        4.99     overcast clouds
# 4         100       23.73     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
